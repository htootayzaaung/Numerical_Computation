# %%
"Simple Iterative method"

x = 0 #initial value of x

print("No degree of accuracy unspecified:\n")
for i in range(100):
    x_new = (2 * (x ** 2) + 3) / 5
    print(f"x{i + 1}: ", x_new, "\n")
    if x_new == x:
        break
    x = x_new
# Out:
# No degree of accuracy unspecified:
#
# x1:  0.6
#
# x2:  0.744
#
# x3:  0.8214144000000001
#
# x4:  0.8698886466109441
#
# x5:  0.902682503001048
#
# x6:  0.925934280489695
#
# x7:  0.9429417167143876
#
# x8:  0.9556556324481106
#
# x9:  0.9653110751319194
#
# x10:  0.9727301887089368
#
# x11:  0.9784816080102896
#
# x12:  0.9829705028857608
#
# x13:  0.9864924038173942
#
# x14:  0.9892669051157682
#
# x15:  0.9914596038229322
#
# x16:  0.9931968584050903
#
# x17:  0.9945759998182965
#
# x18:  0.9956725677658256
#
# x19:  0.9965455448805571
#
# x20:  0.9972412092085147
#
# x21:  0.9977960117374642
#
# x22:  0.998238752415676
#
# x23:  0.998592242729762
#
# x24:  0.9988745868960223
#
# x25:  0.9991001761386796
#
# x26:  0.9992804647841362
#
# x27:  0.9994245789196798
#
# x28:  0.9995397955795117
#
# x29:  0.9996319211788528
#
# x30:  0.9997055911358897
#
# x31:  0.9997645075793435
#
# x32:  0.9998116282461469
#
# x33:  0.9998493167904845
#
# x34:  0.9998794625145594
#
# ...

# %%
x = 0

print("Degree of accuracy specified to 6-decimal places:")
for i in range(100):
    x_new = (2 * (x ** 2) + 3) / 5
    print(f"x{i + 1}: ", x_new, "\n")
    if (x_new - x) < 0.000001:
        break
    x = x_new


"""
The Degree of accuracy

_To satisfy the condition of exact equality between numerical values is extremely difficult if not impossible.

_So, the normal practice in numerical methods is to specify the degree of accuracy required in the solution.
 It reperesents the acceptable absolute maximum difference between values of the variable of the equation resulted
 from the two successive iterations, in other words, the difference between the old and the new values.
"""
# Out:
# Degree of accuracy specified to 6-decimal places:
# x1:  0.6
#
# x2:  0.744
#
# x3:  0.8214144000000001
#
# x4:  0.8698886466109441
#
# x5:  0.902682503001048
#
# x6:  0.925934280489695
#
# x7:  0.9429417167143876
#
# x8:  0.9556556324481106
#
# x9:  0.9653110751319194
#
# x10:  0.9727301887089368
#
# x11:  0.9784816080102896
#
# x12:  0.9829705028857608
#
# x13:  0.9864924038173942
#
# x14:  0.9892669051157682
#
# x15:  0.9914596038229322
#
# x16:  0.9931968584050903
#
# x17:  0.9945759998182965
#
# x18:  0.9956725677658256
#
# x19:  0.9965455448805571
#
# x20:  0.9972412092085147
#
# x21:  0.9977960117374642
#
# x22:  0.998238752415676
#
# x23:  0.998592242729762
#
# x24:  0.9988745868960223
#
# x25:  0.9991001761386796
#
# x26:  0.9992804647841362
#
# x27:  0.9994245789196798
#
# x28:  0.9995397955795117
#
# x29:  0.9996319211788528
#
# x30:  0.9997055911358897
#
# x31:  0.9997645075793435
#
# x32:  0.9998116282461469
#
# x33:  0.9998493167904845
#
# x34:  0.9998794625145594
#
# ...
